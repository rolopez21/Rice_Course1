# %% [markdown]
# # Gotta Catch em All: Listing the Strongest Pokemon

# %% [markdown]
# ## 1. Import Libraries and Dependencies

# %%
# import the module pandas
import pandas as pd
from pathlib import Path

# %% [markdown]
# ## 2. Set the File Path to the CSV using Pathlib

# %%
# Set the path of the Pokemon csv file to be loaded from the Resources folder.
# Define the path name as pokemon_path
pokemon_path = Path("../Resources/Pokemon.csv")

# %% [markdown]
# ## 3. Import the CSV into Pandas DataFrame

# %%
# Define a variable "pokemon_df" and store the Pokemon.csv into Pandas DataFrame using the pokemon_path
pokemon_df = pd.read_csv(pokemon_path)

# Print out the first 5 rows.
pokemon_df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %% [markdown]
# ## 4. View Summary Statistics

# %%
# Use the describe function on pokemon_df to review general info on Total percentiles.
pokemon_df.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# 50%     70.000000   65.000000     3.00000
# 75%     90.000000   90.000000     5.00000
# max    230.000000  180.000000     6.00000

# %% [markdown]
# ## 5. Create Bins for Total Ranking

# %%
# Create the variable bins to define our bounds for when we cut the dataframe.
# Bins are 0, 330, 450, 515, 600, 700, 800
bins = [0, 330, 450, 515, 600, 700, 800]

# Create names for the bins
# group_names to be "Very Weak", "Weak", "Moderate", "Strong", "Very Strong", "Over Powered"
group_names = ["Very Weak", "Weak", "Moderate", "Strong", "Very Strong", "Over Powered"]
pokemon_df
# Out:
#        #                       Name    Type 1  Type 2  Total   HP  Attack  \
# 0      1                  Bulbasaur     Grass  Poison    318   45      49
# 1      2                    Ivysaur     Grass  Poison    405   60      62
# 2      3                   Venusaur     Grass  Poison    525   80      82
# 3      3      VenusaurMega Venusaur     Grass  Poison    625   80     100
# 4      4                 Charmander      Fire     NaN    309   39      52
# 5      5                 Charmeleon      Fire     NaN    405   58      64
# 6      6                  Charizard      Fire  Flying    534   78      84
# 7      6  CharizardMega Charizard X      Fire  Dragon    634   78     130
# 8      6  CharizardMega Charizard Y      Fire  Flying    634   78     104
# 9      7                   Squirtle     Water     NaN    314   44      48
# 10     8                  Wartortle     Water     NaN    405   59      63
# 11     9                  Blastoise     Water     NaN    530   79      83
# 12     9    BlastoiseMega Blastoise     Water     NaN    630   79     103
# 13    10                   Caterpie       Bug     NaN    195   45      30
# 14    11                    Metapod       Bug     NaN    205   50      20
# 15    12                 Butterfree       Bug  Flying    395   60      45
# 16    13                     Weedle       Bug  Poison    195   40      35
# 17    14                     Kakuna       Bug  Poison    205   45      25
# 18    15                   Beedrill       Bug  Poison    395   65      90
# 19    15      BeedrillMega Beedrill       Bug  Poison    495   65     150
# 20    16                     Pidgey    Normal  Flying    251   40      45
# 21    17                  Pidgeotto    Normal  Flying    349   63      60
# 22    18                    Pidgeot    Normal  Flying    479   83      80
# 23    18        PidgeotMega Pidgeot    Normal  Flying    579   83      80
# 24    19                    Rattata    Normal     NaN    253   30      56
# 25    20                   Raticate    Normal     NaN    413   55      81
# 26    21                    Spearow    Normal  Flying    262   40      60
# 27    22                     Fearow    Normal  Flying    442   65      90
# 28    23                      Ekans    Poison     NaN    288   35      60
# 29    24                      Arbok    Poison     NaN    438   60      85
# ..   ...                        ...       ...     ...    ...  ...     ...
# 770  700                    Sylveon     Fairy     NaN    525   95      65
# 771  701                   Hawlucha  Fighting  Flying    500   78      92
# 772  702                    Dedenne  Electric   Fairy    431   67      58
# 773  703                    Carbink      Rock   Fairy    500   50      50
# 774  704                      Goomy    Dragon     NaN    300   45      50
# 775  705                    Sliggoo    Dragon     NaN    452   68      75
# 776  706                     Goodra    Dragon     NaN    600   90     100
# 777  707                     Klefki     Steel   Fairy    470   57      80
# 778  708                   Phantump     Ghost   Grass    309   43      70
# 779  709                  Trevenant     Ghost   Grass    474   85     110
# 780  710      PumpkabooAverage Size     Ghost   Grass    335   49      66
# 781  710        PumpkabooSmall Size     Ghost   Grass    335   44      66
# 782  710        PumpkabooLarge Size     Ghost   Grass    335   54      66
# 783  710        PumpkabooSuper Size     Ghost   Grass    335   59      66
# 784  711      GourgeistAverage Size     Ghost   Grass    494   65      90
# 785  711        GourgeistSmall Size     Ghost   Grass    494   55      85
# 786  711        GourgeistLarge Size     Ghost   Grass    494   75      95
# 787  711        GourgeistSuper Size     Ghost   Grass    494   85     100
# 788  712                   Bergmite       Ice     NaN    304   55      69
# 789  713                    Avalugg       Ice     NaN    514   95     117
# 790  714                     Noibat    Flying  Dragon    245   40      30
# 791  715                    Noivern    Flying  Dragon    535   85      70
# 792  716                    Xerneas     Fairy     NaN    680  126     131
# 793  717                    Yveltal      Dark  Flying    680  126     131
# 794  718           Zygarde50% Forme    Dragon  Ground    600  108     100
# 795  719                    Diancie      Rock   Fairy    600   50     100
# 796  719        DiancieMega Diancie      Rock   Fairy    700   50     160
# 797  720        HoopaHoopa Confined   Psychic   Ghost    600   80     110
# 798  720         HoopaHoopa Unbound   Psychic    Dark    680   80     160
# 799  721                  Volcanion      Fire   Water    600   80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         49       65       65     45           1      False
# 1         63       80       80     60           1      False
# 2         83      100      100     80           1      False
# 3        123      122      120     80           1      False
# 4         43       60       50     65           1      False
# 5         58       80       65     80           1      False
# 6         78      109       85    100           1      False
# 7        111      130       85    100           1      False
# 8         78      159      115    100           1      False
# 9         65       50       64     43           1      False
# 10        80       65       80     58           1      False
# 11       100       85      105     78           1      False
# 12       120      135      115     78           1      False
# 13        35       20       20     45           1      False
# 14        55       25       25     30           1      False
# 15        50       90       80     70           1      False
# 16        30       20       20     50           1      False
# 17        50       25       25     35           1      False
# 18        40       45       80     75           1      False
# 19        40       15       80    145           1      False
# 20        40       35       35     56           1      False
# 21        55       50       50     71           1      False
# 22        75       70       70    101           1      False
# 23        80      135       80    121           1      False
# 24        35       25       35     72           1      False
# 25        60       50       70     97           1      False
# 26        30       31       31     70           1      False
# 27        65       61       61    100           1      False
# 28        44       40       54     55           1      False
# 29        69       65       79     80           1      False
# ..       ...      ...      ...    ...         ...        ...
# 770       65      110      130     60           6      False
# 771       75       74       63    118           6      False
# 772       57       81       67    101           6      False
# 773      150       50      150     50           6      False
# 774       35       55       75     40           6      False
# 775       53       83      113     60           6      False
# 776       70      110      150     80           6      False
# 777       91       80       87     75           6      False
# 778       48       50       60     38           6      False
# 779       76       65       82     56           6      False
# 780       70       44       55     51           6      False
# 781       70       44       55     56           6      False
# 782       70       44       55     46           6      False
# 783       70       44       55     41           6      False
# 784      122       58       75     84           6      False
# 785      122       58       75     99           6      False
# 786      122       58       75     69           6      False
# 787      122       58       75     54           6      False
# 788       85       32       35     28           6      False
# 789      184       44       46     28           6      False
# 790       35       45       40     55           6      False
# 791       80       97       80    123           6      False
# 792       95      131       98     99           6       True
# 793       95      131       98     99           6       True
# 794      121       81       95     95           6       True
# 795      150      100      150     50           6       True
# 796      110      160      110    110           6       True
# 797       60      150      130     70           6       True
# 798       60      170      130     80           6       True
# 799      120      130       90     70           6       True
#
# [800 rows x 13 columns]

# %% [markdown]
# ## 6. Label Records According to the Corresponding Bin

# %%
# Add a column named "Total Ranking" to pokemon_df and slice the data into the bins
pokemon_df["Total Ranking"] = pd.cut(pokemon_df["Total"], bins, labels=group_names)

# Print out the first 10 rows of pokemon_df.
pokemon_df.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary Total Ranking
# 0       65       65     45           1      False     Very Weak
# 1       80       80     60           1      False          Weak
# 2      100      100     80           1      False        Strong
# 3      122      120     80           1      False   Very Strong
# 4       60       50     65           1      False     Very Weak
# 5       80       65     80           1      False          Weak
# 6      109       85    100           1      False        Strong
# 7      130       85    100           1      False   Very Strong
# 8      159      115    100           1      False   Very Strong
# 9       50       64     43           1      False     Very Weak

# %% [markdown]
# ## 7. Set the Index to the DataFrame

# %%
# Set new index to Total Ranking
pokemon_df = pokemon_df.set_index("Total Ranking")
pokemon_df
# Out:
#                  #                       Name    Type 1  Type 2  Total   HP  \
# Total Ranking
# Very Weak        1                  Bulbasaur     Grass  Poison    318   45
# Weak             2                    Ivysaur     Grass  Poison    405   60
# Strong           3                   Venusaur     Grass  Poison    525   80
# Very Strong      3      VenusaurMega Venusaur     Grass  Poison    625   80
# Very Weak        4                 Charmander      Fire     NaN    309   39
# Weak             5                 Charmeleon      Fire     NaN    405   58
# Strong           6                  Charizard      Fire  Flying    534   78
# Very Strong      6  CharizardMega Charizard X      Fire  Dragon    634   78
# Very Strong      6  CharizardMega Charizard Y      Fire  Flying    634   78
# Very Weak        7                   Squirtle     Water     NaN    314   44
# Weak             8                  Wartortle     Water     NaN    405   59
# Strong           9                  Blastoise     Water     NaN    530   79
# Very Strong      9    BlastoiseMega Blastoise     Water     NaN    630   79
# Very Weak       10                   Caterpie       Bug     NaN    195   45
# Very Weak       11                    Metapod       Bug     NaN    205   50
# Weak            12                 Butterfree       Bug  Flying    395   60
# Very Weak       13                     Weedle       Bug  Poison    195   40
# Very Weak       14                     Kakuna       Bug  Poison    205   45
# Weak            15                   Beedrill       Bug  Poison    395   65
# Moderate        15      BeedrillMega Beedrill       Bug  Poison    495   65
# Very Weak       16                     Pidgey    Normal  Flying    251   40
# Weak            17                  Pidgeotto    Normal  Flying    349   63
# Moderate        18                    Pidgeot    Normal  Flying    479   83
# Strong          18        PidgeotMega Pidgeot    Normal  Flying    579   83
# Very Weak       19                    Rattata    Normal     NaN    253   30
# Weak            20                   Raticate    Normal     NaN    413   55
# Very Weak       21                    Spearow    Normal  Flying    262   40
# Weak            22                     Fearow    Normal  Flying    442   65
# Very Weak       23                      Ekans    Poison     NaN    288   35
# Weak            24                      Arbok    Poison     NaN    438   60
# ...            ...                        ...       ...     ...    ...  ...
# Strong         700                    Sylveon     Fairy     NaN    525   95
# Moderate       701                   Hawlucha  Fighting  Flying    500   78
# Weak           702                    Dedenne  Electric   Fairy    431   67
# Moderate       703                    Carbink      Rock   Fairy    500   50
# Very Weak      704                      Goomy    Dragon     NaN    300   45
# Moderate       705                    Sliggoo    Dragon     NaN    452   68
# Strong         706                     Goodra    Dragon     NaN    600   90
# Moderate       707                     Klefki     Steel   Fairy    470   57
# Very Weak      708                   Phantump     Ghost   Grass    309   43
# Moderate       709                  Trevenant     Ghost   Grass    474   85
# Weak           710      PumpkabooAverage Size     Ghost   Grass    335   49
# Weak           710        PumpkabooSmall Size     Ghost   Grass    335   44
# Weak           710        PumpkabooLarge Size     Ghost   Grass    335   54
# Weak           710        PumpkabooSuper Size     Ghost   Grass    335   59
# Moderate       711      GourgeistAverage Size     Ghost   Grass    494   65
# Moderate       711        GourgeistSmall Size     Ghost   Grass    494   55
# Moderate       711        GourgeistLarge Size     Ghost   Grass    494   75
# Moderate       711        GourgeistSuper Size     Ghost   Grass    494   85
# Very Weak      712                   Bergmite       Ice     NaN    304   55
# Moderate       713                    Avalugg       Ice     NaN    514   95
# Very Weak      714                     Noibat    Flying  Dragon    245   40
# Strong         715                    Noivern    Flying  Dragon    535   85
# Very Strong    716                    Xerneas     Fairy     NaN    680  126
# Very Strong    717                    Yveltal      Dark  Flying    680  126
# Strong         718           Zygarde50% Forme    Dragon  Ground    600  108
# Strong         719                    Diancie      Rock   Fairy    600   50
# Very Strong    719        DiancieMega Diancie      Rock   Fairy    700   50
# Strong         720        HoopaHoopa Confined   Psychic   Ghost    600   80
# Very Strong    720         HoopaHoopa Unbound   Psychic    Dark    680   80
# Strong         721                  Volcanion      Fire   Water    600   80
#
#                Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# Total Ranking
# Very Weak          49       49       65       65     45           1      False
# Weak               62       63       80       80     60           1      False
# Strong             82       83      100      100     80           1      False
# Very Strong       100      123      122      120     80           1      False
# Very Weak          52       43       60       50     65           1      False
# Weak               64       58       80       65     80           1      False
# Strong             84       78      109       85    100           1      False
# Very Strong       130      111      130       85    100           1      False
# Very Strong       104       78      159      115    100           1      False
# Very Weak          48       65       50       64     43           1      False
# Weak               63       80       65       80     58           1      False
# Strong             83      100       85      105     78           1      False
# Very Strong       103      120      135      115     78           1      False
# Very Weak          30       35       20       20     45           1      False
# Very Weak          20       55       25       25     30           1      False
# Weak               45       50       90       80     70           1      False
# Very Weak          35       30       20       20     50           1      False
# Very Weak          25       50       25       25     35           1      False
# Weak               90       40       45       80     75           1      False
# Moderate          150       40       15       80    145           1      False
# Very Weak          45       40       35       35     56           1      False
# Weak               60       55       50       50     71           1      False
# Moderate           80       75       70       70    101           1      False
# Strong             80       80      135       80    121           1      False
# Very Weak          56       35       25       35     72           1      False
# Weak               81       60       50       70     97           1      False
# Very Weak          60       30       31       31     70           1      False
# Weak               90       65       61       61    100           1      False
# Very Weak          60       44       40       54     55           1      False
# Weak               85       69       65       79     80           1      False
# ...               ...      ...      ...      ...    ...         ...        ...
# Strong             65       65      110      130     60           6      False
# Moderate           92       75       74       63    118           6      False
# Weak               58       57       81       67    101           6      False
# Moderate           50      150       50      150     50           6      False
# Very Weak          50       35       55       75     40           6      False
# Moderate           75       53       83      113     60           6      False
# Strong            100       70      110      150     80           6      False
# Moderate           80       91       80       87     75           6      False
# Very Weak          70       48       50       60     38           6      False
# Moderate          110       76       65       82     56           6      False
# Weak               66       70       44       55     51           6      False
# Weak               66       70       44       55     56           6      False
# Weak               66       70       44       55     46           6      False
# Weak               66       70       44       55     41           6      False
# Moderate           90      122       58       75     84           6      False
# Moderate           85      122       58       75     99           6      False
# Moderate           95      122       58       75     69           6      False
# Moderate          100      122       58       75     54           6      False
# Very Weak          69       85       32       35     28           6      False
# Moderate          117      184       44       46     28           6      False
# Very Weak          30       35       45       40     55           6      False
# Strong             70       80       97       80    123           6      False
# Very Strong       131       95      131       98     99           6       True
# Very Strong       131       95      131       98     99           6       True
# Strong            100      121       81       95     95           6       True
# Strong            100      150      100      150     50           6       True
# Very Strong       160      110      160      110    110           6       True
# Strong            110       60      150      130     70           6       True
# Very Strong       160       60      170      130     80           6       True
# Strong            110      120      130       90     70           6       True
#
# [800 rows x 13 columns]

# %% [markdown]
# ## 8. Filter Down to the Strongest Pokemon

# %%
# Set the variable overpowered_df to be the pokemon dataframe with Over Powered only.
overpowered_df = pd.DataFrame(pokemon_df.loc["Over Powered"])
overpowered_df
# Out:
#                  #                   Name   Type 1    Type 2  Total   HP  \
# Total Ranking
# Over Powered   150    MewtwoMega Mewtwo X  Psychic  Fighting    780  106
# Over Powered   150    MewtwoMega Mewtwo Y  Psychic       NaN    780  106
# Over Powered   382    KyogrePrimal Kyogre    Water       NaN    770  100
# Over Powered   383  GroudonPrimal Groudon   Ground      Fire    770  100
# Over Powered   384  RayquazaMega Rayquaza   Dragon    Flying    780  105
# Over Powered   493                 Arceus   Normal       NaN    720  120
#
#                Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# Total Ranking
# Over Powered      190      100      154      100    130           1       True
# Over Powered      150       70      194      120    140           1       True
# Over Powered      150       90      180      160     90           3       True
# Over Powered      180      160      150       90     90           3       True
# Over Powered      180      100      180      100    115           3       True
# Over Powered      120      120      120      120    120           4       True
