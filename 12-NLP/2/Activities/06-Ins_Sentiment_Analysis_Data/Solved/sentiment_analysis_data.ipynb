# %% [markdown]
# # Instructor Do: Getting Data for Sentiment Analysis

# %%
# Initial imports
import os
import pandas as pd
from newsapi import NewsApiClient

# %%
# Reading the News API key enviroment variable
api_key = os.getenv("news_api")

# %%
api_key

# %%
# Create a newsapi client
newsapi = NewsApiClient(api_key=api_key)

# %%
# Fetch top news articles about oil
oil_headlines = newsapi.get_top_headlines(q="oil", language="en", country="us")
oil_headlines
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-59feea2dc2ee> in <module>
#       1 # Fetch top news articles about oil
# ----> 2 oil_headlines = newsapi.get_top_headlines(q="oil", language="en", country="us")
#       3 oil_headlines
#       4
#
# /anaconda3/envs/vizenv/lib/python3.7/site-packages/newsapi/newsapi_client.py in get_top_headlines(self, q, sources, language, country, category, page_size, page)
#     113
#     114         # Send Request
# --> 115         r = requests.get(const.TOP_HEADLINES_URL, auth=self.auth, timeout=30, params=payload)
#     116
#     117         # Check Status of Request
#
# /anaconda3/envs/vizenv/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# /anaconda3/envs/vizenv/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# /anaconda3/envs/vizenv/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# /anaconda3/envs/vizenv/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# /anaconda3/envs/vizenv/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# /anaconda3/envs/vizenv/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# /anaconda3/envs/vizenv/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     352             conn.request_chunked(method, url, **httplib_request_kw)
#     353         else:
# --> 354             conn.request(method, url, **httplib_request_kw)
#     355
#     356         # Reset the timeout for the recv() on the socket
#
# /anaconda3/envs/vizenv/lib/python3.7/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1227                 encode_chunked=False):
#    1228         """Send a complete request to the server."""
# -> 1229         self._send_request(method, url, body, headers, encode_chunked)
#    1230
#    1231     def _send_request(self, method, url, body, headers, encode_chunked):
#
# /anaconda3/envs/vizenv/lib/python3.7/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1268
#    1269         for hdr, value in headers.items():
# -> 1270             self.putheader(hdr, value)
#    1271         if isinstance(body, str):
#    1272             # RFC 2616 Section 3.7.1 says that text default has a
#
# /anaconda3/envs/vizenv/lib/python3.7/http/client.py in putheader(self, header, *values)
#    1204                 values[i] = str(one_value).encode('ascii')
#    1205
# -> 1206             if _is_illegal_header_value(values[i]):
#    1207                 raise ValueError('Invalid header value %r' % (values[i],))
#    1208
#
# TypeError: expected string or bytes-like object

# %%
# Print total articles
print(f"Total articles about oil: {oil_headlines['totalResults']}")

# Show sample article
oil_headlines["articles"][0]

# %%
# Transform the response dictionary to a DataFrame
oil_df = pd.DataFrame.from_dict(oil_headlines["articles"])

oil_df.head()

# %%
# Fetch all the news about Facebook Libra
libra_headlines = newsapi.get_everything(
    q="facebook libra", language="en", sort_by="relevancy"
)

# Print total articles
print(f"Total articles about Facebook Libra: {libra_headlines['totalResults']}")

# Show sample article
libra_headlines["articles"][0]

# %%
# Transform the response dictionary to a DataFrame
libra_df = pd.DataFrame.from_dict(libra_headlines["articles"])

libra_df.head()
