# %%
import requests

# %%
# Create variable to hold request url
url = "http://api.worldbank.org/v2/country/all/indicator/NY.GDP.MKTP.CD"

# %%
# Add format specifier to request url
url = url + "?format=json"

# %% [markdown]
# ### Execute GET request with URL

# %%
# Execute get request
requests.get(url)
# Out:
# <Response [200]>

# %% [markdown]
# ### Store response as variable

# %%
# Execute GET request and store response
response_data = requests.get(url)

# %% [markdown]
# ### Retrieve API output using `content` attribute

# %%
# Get content
response_content = response_data.content
print(response_content)
# Out:
# b'[{"page":1,"pages":330,"per_page":50,"total":16492,"sourceid":"2","sourcename":"World Development Indicators","lastupdated":"2022-07-20"},[{"indicator":{"id":"NY.GDP.MKTP.CD","value":"GDP (current US$)"},"country":{"id":"ZH","value":"Africa Eastern and Southern"},"countryiso3code":"AFE","date":"2021","value":1082095608968.23,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"NY.GDP.MKTP.CD","value":"GDP (current US$)"},"country":{"id":"ZH","value":"Africa Eastern and Southern"},"countryiso3code":"AFE","date":"2020","value":921645942921.888,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"NY.GDP.MKTP.CD","value":"GDP (current US$)"},"country":{"id":"ZH","value":"Africa Eastern and Southern"},"countryiso3code":"AFE","date":"2019","value":997534042075.187,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"NY.GDP.MKTP.CD","value":"GDP (current US$)"},"country":{"id":"ZH","value":"Africa Eastern and Southern"},"countryiso3code":"AFE","date":"2018","value":991022252916.702,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"NY.GDP.MKTP.CD","value":"GDP (current US$)"},"country":{"id":"ZH","value":"Africa Eastern and Southern"},"countryiso3code":"AFE","date":"2017","value":1020647235171.22,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"NY.GDP.MKTP.CD","value":"GDP (current US$)"},"country":{"id":"ZH","value":"Africa Eastern and Southern"},"countryiso3code":"AFE","date":"2016","value":882355055412.759,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"NY.GDP.MKTP.CD","value":"GDP (current US$)"},"country":{"id":"ZH","value":"Africa Eastern and Southern"},"countryiso3code":"AFE","date":"2015","value":924252536256.503,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"NY.GDP.MKTP.CD","value":"GDP (current US$)"},"country":{"id":"ZH","value":"Africa Eastern and Southern"},"countryiso3code":"AFE","date":"2014","value":1003678868706.97,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"NY.GDP.MKTP.CD","value":"GDP (current US$)"},"country":{"id":"ZH","value":"Africa Eastern and Southern"},"countryiso3code":"AFE","date":"2013","value":983937046710.893,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"NY.GDP.MKTP.CD","value":"GDP (current US$)"},"country":{"id":"ZH","value":"Africa Eastern and Southern"},"countryiso3code":"AFE","date":"2012","value":973043454994.634,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"NY.GDP.MKTP.CD","value":"GDP (current US$)"},"country":{"id":"ZH","value":"Africa Eastern and Southern"},"countryiso3code":"AFE","date":"2011","value":964418457187.791,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"NY.GDP.MKTP.CD","value":"GDP (current US$)"},"country":{"id":"ZH","value":"Africa Eastern and Southern"},"countryiso3code":"AFE","date":"2010","value":860478348236.464,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"NY.GDP.MKTP.CD","value":"GDP (current US$)"},"country":{"id":"ZH","value":"Africa Eastern and Southern"},"countryiso3code":"AFE","date":"2009","value":719216656140.903,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"NY.GDP.MKTP.CD","value":"GDP (current US$)"},"country":{"id":"ZH","value":"Africa Eastern and Southern"},"countryiso3code":"AFE","date":"2008","value":708286928848.111,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"NY.GDP.MKTP.CD","value":"GDP (current US$)"},"country":{"id":"ZH","value":"Africa Eastern and Southern"},"countryiso3code":"AFE","date":"2007","value":661179291210.003,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"NY.GDP.MKTP.CD","value":"GDP (current US$)"},"country":{"id":"ZH","value":"Africa Eastern and Southern"},"countryiso3code":"AFE","date":"2006","value":575921416503.73,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"NY.GDP.MKTP.CD","value":"GDP (current US$)"},"country":{"id":"ZH","value":"Africa Eastern and Southern"},"countryiso3code":"AFE","date":"2005","value":512211130671.035,"unit":"","obs_status":"","decimal":0},{ ...

# %% [markdown]
# ### Use `json` function from `json` library to format

# %%
import json

# Formatting as json
data = response_data.json()

# %% [markdown]
# ### Format JSON with indents

# %%
# Add indents to JSON and output to screen
print(json.dumps(data, indent=4))
# Out:
# [
#     {
#         "page": 1,
#         "pages": 330,
#         "per_page": 50,
#         "total": 16492,
#         "sourceid": "2",
#         "sourcename": "World Development Indicators",
#         "lastupdated": "2022-07-20"
#     },
#     [
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "2021",
#             "value": 1082095608968.23,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "2020",
#             "value": 921645942921.888,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "2019",
#             "value": 997534042075.187,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "2018",
#             "value": 991022252916.702,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "2017",
#             "value": 1020647235171.22,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "2016",
#             "value": 882355055412.759,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "2015",
#             "value": 924252536256.503,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "2014",
#             "value": 1003678868706.97,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "2013",
#             "value": 983937046710.893,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "2012",
#             "value": 973043454994.634,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "2011",
#             "value": 964418457187.791,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "2010",
#             "value": 860478348236.464,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "2009",
#             "value": 719216656140.903,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "2008",
#             "value": 708286928848.111,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "2007",
#             "value": 661179291210.003,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "2006",
#             "value": 575921416503.73,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "2005",
#             "value": 512211130671.035,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "2004",
#             "value": 438833793854.258,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "2003",
#             "value": 352658503930.87,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "2002",
#             "value": 264869812959.289,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "2001",
#             "value": 258818573322.586,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "2000",
#             "value": 283925424524.95,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "1999",
#             "value": 262172198957.447,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "1998",
#             "value": 265814093139.907,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "1997",
#             "value": 282184986870.201,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "1996",
#             "value": 268413689898.383,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "1995",
#             "value": 269636854385.978,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "1994",
#             "value": 240120093424.591,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "1993",
#             "value": 236526919099.008,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "1992",
#             "value": 238255441287.563,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "1991",
#             "value": 273402805408.616,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "1990",
#             "value": 253224041095.044,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "1989",
#             "value": 217538592168.933,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "1988",
#             "value": 204139844556.652,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "1987",
#             "value": 186144649622.386,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "1986",
#             "value": 152518294683.987,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "1985",
#             "value": 136297338029.871,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "1984",
#             "value": 160133966253.813,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "1983",
#             "value": 174918045686.543,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "1982",
#             "value": 167266313060.902,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "1981",
#             "value": 174387007968.082,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "1980",
#             "value": 170654335897.028,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "1979",
#             "value": 134671404724.684,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "1978",
#             "value": 115345041829.637,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "1977",
#             "value": 103415844082.068,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "1976",
#             "value": 91124551925.9133,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "1975",
#             "value": 91649152686.8653,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "1974",
#             "value": 86057777550.911,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "1973",
#             "value": 69600788110.6735,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "ZH",
#                 "value": "Africa Eastern and Southern"
#             },
#             "countryiso3code": "AFE",
#             "date": "1972",
#             "value": 53514844533.891,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         }
#     ]
# ]

# %% [markdown]
# ### Identify country and GDP value for first row

# %%
# Select country and GDP value for first row
country = data[1][1]['country']['value']
gdp_value = data[1][1]['value']

print("Country: " + country)
print("GDP Value: " + str(gdp_value))
# Out:
# Country: Africa Eastern and Southern
# GDP Value: 921645942921.888
