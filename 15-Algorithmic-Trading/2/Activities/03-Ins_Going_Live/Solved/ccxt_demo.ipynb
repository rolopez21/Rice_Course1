# %% [markdown]
# # Going Live with CCXT

# %% [markdown]
# ### Import Libraries and Dependencies

# %%
# Import libraries and dependencies
import ccxt
import os
import pandas as pd

# %% [markdown]
# ### Import Environment Variables

# %%
# Import environment variables
kraken_public_key = os.getenv('KRAKEN_PUBLIC_KEY')
kraken_secret_key = os.getenv('KRAKEN_SECRET_KEY')

# %% [markdown]
# ### Set Public and Private Keys for Kraken Exchange via the CCXT library

# %%
# Set the public and private keys for the API
exchange = ccxt.kraken({
    'apiKey': kraken_public_key,
    'secret': kraken_secret_key,
})

# %% [markdown]
# ### Connect to Kraken and Load Available Cyptocurrency Data

# %%
# Connect to Kraken and load the available cyptocurrencies
crypto_details = exchange.load_markets()

# Import data as a Pandas DataFrame
crypto_df = pd.DataFrame(crypto_details)
crypto_df
# Out:
#                                                       ADA/CAD  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 6}
# limits      {'amount': {'min': 1.0, 'max': 100000000.0}, '...
# id                                                     ADACAD
# symbol                                                ADA/CAD
# base                                                      ADA
# quote                                                     CAD
# baseId                                                    ADA
# quoteId                                                  ZCAD
# darkpool                                                False
# info        {'altname': 'ADACAD', 'wsname': 'ADA/CAD', 'ac...
# altname                                                ADACAD
# active                                                   True
#
#                                                       ADA/ETH  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 7}
# limits      {'amount': {'min': 1.0, 'max': 100000000.0}, '...
# id                                                     ADAETH
# symbol                                                ADA/ETH
# base                                                      ADA
# quote                                                     ETH
# baseId                                                    ADA
# quoteId                                                  XETH
# darkpool                                                False
# info        {'altname': 'ADAETH', 'wsname': 'ADA/ETH', 'ac...
# altname                                                ADAETH
# active                                                   True
#
#                                                       ADA/EUR  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 6}
# limits      {'amount': {'min': 1.0, 'max': 100000000.0}, '...
# id                                                     ADAEUR
# symbol                                                ADA/EUR
# base                                                      ADA
# quote                                                     EUR
# baseId                                                    ADA
# quoteId                                                  ZEUR
# darkpool                                                False
# info        {'altname': 'ADAEUR', 'wsname': 'ADA/EUR', 'ac...
# altname                                                ADAEUR
# active                                                   True
#
#                                                       ADA/USD  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 6}
# limits      {'amount': {'min': 1.0, 'max': 100000000.0}, '...
# id                                                     ADAUSD
# symbol                                                ADA/USD
# base                                                      ADA
# quote                                                     USD
# baseId                                                    ADA
# quoteId                                                  ZUSD
# darkpool                                                False
# info        {'altname': 'ADAUSD', 'wsname': 'ADA/USD', 'ac...
# altname                                                ADAUSD
# active                                                   True
#
#                                                       ADA/BTC  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 8}
# limits      {'amount': {'min': 1.0, 'max': 100000000.0}, '...
# id                                                     ADAXBT
# symbol                                                ADA/BTC
# base                                                      ADA
# quote                                                     BTC
# baseId                                                    ADA
# quoteId                                                  XXBT
# darkpool                                                False
# info        {'altname': 'ADAXBT', 'wsname': 'ADA/XBT', 'ac...
# altname                                                ADAXBT
# active                                                   True
#
#                                                      ATOM/CAD  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 4}
# limits      {'amount': {'min': 1.0, 'max': 100000000.0}, '...
# id                                                    ATOMCAD
# symbol                                               ATOM/CAD
# base                                                     ATOM
# quote                                                     CAD
# baseId                                                   ATOM
# quoteId                                                  ZCAD
# darkpool                                                False
# info        {'altname': 'ATOMCAD', 'wsname': 'ATOM/CAD', '...
# altname                                               ATOMCAD
# active                                                   True
#
#                                                      ATOM/ETH  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 6}
# limits      {'amount': {'min': 1.0, 'max': 100000000.0}, '...
# id                                                    ATOMETH
# symbol                                               ATOM/ETH
# base                                                     ATOM
# quote                                                     ETH
# baseId                                                   ATOM
# quoteId                                                  XETH
# darkpool                                                False
# info        {'altname': 'ATOMETH', 'wsname': 'ATOM/ETH', '...
# altname                                               ATOMETH
# active                                                   True
#
#                                                      ATOM/EUR  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 4}
# limits      {'amount': {'min': 1.0, 'max': 100000000.0}, '...
# id                                                    ATOMEUR
# symbol                                               ATOM/EUR
# base                                                     ATOM
# quote                                                     EUR
# baseId                                                   ATOM
# quoteId                                                  ZEUR
# darkpool                                                False
# info        {'altname': 'ATOMEUR', 'wsname': 'ATOM/EUR', '...
# altname                                               ATOMEUR
# active                                                   True
#
#                                                      ATOM/USD  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 4}
# limits      {'amount': {'min': 1.0, 'max': 100000000.0}, '...
# id                                                    ATOMUSD
# symbol                                               ATOM/USD
# base                                                     ATOM
# quote                                                     USD
# baseId                                                   ATOM
# quoteId                                                  ZUSD
# darkpool                                                False
# info        {'altname': 'ATOMUSD', 'wsname': 'ATOM/USD', '...
# altname                                               ATOMUSD
# active                                                   True
#
#                                                      ATOM/BTC  ...  \
# percentage                                               True  ...
# tierBased                                                True  ...
# taker                                                  0.0026  ...
# maker                                                  0.0016  ...
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...  ...
# precision                           {'amount': 8, 'price': 7}  ...
# limits      {'amount': {'min': 1.0, 'max': 100000000.0}, '...  ...
# id                                                    ATOMXBT  ...
# symbol                                               ATOM/BTC  ...
# base                                                     ATOM  ...
# quote                                                     BTC  ...
# baseId                                                   ATOM  ...
# quoteId                                                  XXBT  ...
# darkpool                                                False  ...
# info        {'altname': 'ATOMXBT', 'wsname': 'ATOM/XBT', '...  ...
# altname                                               ATOMXBT  ...
# active                                                   True  ...
#
#                                                       XMR/USD  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 2}
# limits      {'amount': {'min': 0.1, 'max': 100000000.0}, '...
# id                                                   XXMRZUSD
# symbol                                                XMR/USD
# base                                                      XMR
# quote                                                     USD
# baseId                                                   XXMR
# quoteId                                                  ZUSD
# darkpool                                                False
# info        {'altname': 'XMRUSD', 'wsname': 'XMR/USD', 'ac...
# altname                                                XMRUSD
# active                                                   True
#
#                                                       XRP/BTC  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 8}
# limits      {'amount': {'min': 30.0, 'max': 100000000.0}, ...
# id                                                   XXRPXXBT
# symbol                                                XRP/BTC
# base                                                      XRP
# quote                                                     BTC
# baseId                                                   XXRP
# quoteId                                                  XXBT
# darkpool                                                False
# info        {'altname': 'XRPXBT', 'wsname': 'XRP/XBT', 'ac...
# altname                                                XRPXBT
# active                                                   True
#
#                                                       XRP/CAD  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 5}
# limits      {'amount': {'min': 30.0, 'max': 100000000.0}, ...
# id                                                   XXRPZCAD
# symbol                                                XRP/CAD
# base                                                      XRP
# quote                                                     CAD
# baseId                                                   XXRP
# quoteId                                                  ZCAD
# darkpool                                                False
# info        {'altname': 'XRPCAD', 'wsname': 'XRP/CAD', 'ac...
# altname                                                XRPCAD
# active                                                   True
#
#                                                       XRP/EUR  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 5}
# limits      {'amount': {'min': 30.0, 'max': 100000000.0}, ...
# id                                                   XXRPZEUR
# symbol                                                XRP/EUR
# base                                                      XRP
# quote                                                     EUR
# baseId                                                   XXRP
# quoteId                                                  ZEUR
# darkpool                                                False
# info        {'altname': 'XRPEUR', 'wsname': 'XRP/EUR', 'ac...
# altname                                                XRPEUR
# active                                                   True
#
#                                                       XRP/JPY  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 3}
# limits      {'amount': {'min': 30.0, 'max': 100000000.0}, ...
# id                                                   XXRPZJPY
# symbol                                                XRP/JPY
# base                                                      XRP
# quote                                                     JPY
# baseId                                                   XXRP
# quoteId                                                  ZJPY
# darkpool                                                False
# info        {'altname': 'XRPJPY', 'wsname': 'XRP/JPY', 'ac...
# altname                                                XRPJPY
# active                                                   True
#
#                                                       XRP/USD  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 5}
# limits      {'amount': {'min': 30.0, 'max': 100000000.0}, ...
# id                                                   XXRPZUSD
# symbol                                                XRP/USD
# base                                                      XRP
# quote                                                     USD
# baseId                                                   XXRP
# quoteId                                                  ZUSD
# darkpool                                                False
# info        {'altname': 'XRPUSD', 'wsname': 'XRP/USD', 'ac...
# altname                                                XRPUSD
# active                                                   True
#
#                                                       ZEC/BTC  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 5}
# limits      {'amount': {'min': 0.03, 'max': 100000000.0}, ...
# id                                                   XZECXXBT
# symbol                                                ZEC/BTC
# base                                                      ZEC
# quote                                                     BTC
# baseId                                                   XZEC
# quoteId                                                  XXBT
# darkpool                                                False
# info        {'altname': 'ZECXBT', 'wsname': 'ZEC/XBT', 'ac...
# altname                                                ZECXBT
# active                                                   True
#
#                                                       ZEC/EUR  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 3}
# limits      {'amount': {'min': 0.03, 'max': 100000000.0}, ...
# id                                                   XZECZEUR
# symbol                                                ZEC/EUR
# base                                                      ZEC
# quote                                                     EUR
# baseId                                                   XZEC
# quoteId                                                  ZEUR
# darkpool                                                False
# info        {'altname': 'ZECEUR', 'wsname': 'ZEC/EUR', 'ac...
# altname                                                ZECEUR
# active                                                   True
#
#                                                       ZEC/JPY  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 3}
# limits      {'amount': {'min': 0.03, 'max': 100000000.0}, ...
# id                                                   XZECZJPY
# symbol                                                ZEC/JPY
# base                                                      ZEC
# quote                                                     JPY
# baseId                                                   XZEC
# quoteId                                                  ZJPY
# darkpool                                                False
# info        {'altname': 'ZECJPY', 'wsname': 'ZEC/JPY', 'ac...
# altname                                                ZECJPY
# active                                                   True
#
#                                                       ZEC/USD
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 2}
# limits      {'amount': {'min': 0.03, 'max': 100000000.0}, ...
# id                                                   XZECZUSD
# symbol                                                ZEC/USD
# base                                                      ZEC
# quote                                                     USD
# baseId                                                   XZEC
# quoteId                                                  ZUSD
# darkpool                                                False
# info        {'altname': 'ZECUSD', 'wsname': 'ZEC/USD', 'ac...
# altname                                                ZECUSD
# active                                                   True
#
# [17 rows x 118 columns]

# %% [markdown]
# ### List Available Cryptocurrencies for Trading

# %%
# Print column values of DataFrame
print(type(crypto_df.columns.values))
print(crypto_df.columns.values)
print(len(crypto_df.columns.values))
# Out:
# <class 'numpy.ndarray'>
# ['ADA/CAD' 'ADA/ETH' 'ADA/EUR' 'ADA/USD' 'ADA/BTC' 'ATOM/CAD' 'ATOM/ETH'
#  'ATOM/EUR' 'ATOM/USD' 'ATOM/BTC' 'BAT/ETH' 'BAT/EUR' 'BAT/USD' 'BAT/BTC'
#  'BCH/EUR' 'BCH/USD' 'BCH/BTC' 'DAI/EUR' 'DAI/USD' 'DAI/USDT' 'DASH/EUR'
#  'DASH/USD' 'DASH/BTC' 'EOS/ETH' 'EOS/EUR' 'EOS/USD' 'EOS/BTC' 'ETH/DAI'
#  'GNO/ETH' 'GNO/EUR' 'GNO/USD' 'GNO/BTC' 'ICX/ETH' 'ICX/EUR' 'ICX/USD'
#  'ICX/BTC' 'LINK/ETH' 'LINK/EUR' 'LINK/USD' 'LINK/BTC' 'OMG/ETH' 'OMG/EUR'
#  'OMG/USD' 'OMG/BTC' 'PAXG/ETH' 'PAXG/EUR' 'PAXG/USD' 'PAXG/BTC'
#  'QTUM/CAD' 'QTUM/ETH' 'QTUM/EUR' 'QTUM/USD' 'QTUM/BTC' 'SC/ETH' 'SC/EUR'
#  'SC/USD' 'SC/BTC' 'USDT/USD' 'WAVES/ETH' 'WAVES/EUR' 'WAVES/USD'
#  'WAVES/BTC' 'ETC/ETH' 'ETC/BTC' 'ETC/EUR' 'ETC/USD' 'ETH/BTC' 'ETHXBT.d'
#  'ETH/CAD' 'ETHCAD.d' 'ETH/EUR' 'ETHEUR.d' 'ETH/GBP' 'ETHGBP.d' 'ETH/JPY'
#  'ETHJPY.d' 'ETH/USD' 'ETHUSD.d' 'LTC/BTC' 'LTC/EUR' 'LTC/USD' 'MLN/ETH'
#  'MLN/BTC' 'REP/ETH' 'REP/BTC' 'REP/EUR' 'REP/USD' 'XTZ/CAD' 'XTZ/ETH'
#  'XTZ/EUR' 'XTZ/USD' 'XTZ/BTC' 'BTC/CAD' 'XBTCAD.d' 'BTC/EUR' 'XBTEUR.d'
#  'BTC/GBP' 'XBTGBP.d' 'BTC/JPY' 'XBTJPY.d' 'BTC/USD' 'XBTUSD.d' 'DOGE/BTC'
#  'XLM/BTC' 'XLM/EUR' 'XLM/USD' 'XMR/BTC' 'XMR/EUR' 'XMR/USD' 'XRP/BTC'
#  'XRP/CAD' 'XRP/EUR' 'XRP/JPY' 'XRP/USD' 'ZEC/BTC' 'ZEC/EUR' 'ZEC/JPY'
#  'ZEC/USD']
# 118

# %%
# Show list of available functions for the current exchange (in this case Kraken)
exchange.has
# Out:
# {'cancelAllOrders': False,
#  'cancelOrder': True,
#  'cancelOrders': False,
#  'CORS': False,
#  'createDepositAddress': True,
#  'createLimitOrder': True,
#  'createMarketOrder': True,
#  'createOrder': True,
#  'deposit': False,
#  'editOrder': 'emulated',
#  'fetchBalance': True,
#  'fetchClosedOrders': True,
#  'fetchCurrencies': True,
#  'fetchDepositAddress': True,
#  'fetchDeposits': True,
#  'fetchL2OrderBook': True,
#  'fetchLedger': True,
#  'fetchMarkets': True,
#  'fetchMyTrades': True,
#  'fetchOHLCV': True,
#  'fetchOpenOrders': True,
#  'fetchOrder': True,
#  'fetchOrderBook': True,
#  'fetchOrderBooks': False,
#  'fetchOrders': False,
#  'fetchStatus': 'emulated',
#  'fetchTicker': True,
#  'fetchTickers': True,
#  'fetchTime': False,
#  'fetchTrades': True,
#  'fetchTradingFee': True,
#  'fetchTradingFees': True,
#  'fetchFundingFee': False,
#  'fetchFundingFees': False,
#  'fetchTradingLimits': False,
#  'fetchTransactions': False,
#  'fetchWithdrawals': True,
#  'privateAPI': True,
#  'publicAPI': True,
#  'withdraw': True,
#  'fetchLedgerEntry': True}

# %% [markdown]
# ### Fetch Historical Data for BTC/USD

# %%
# Fetch daily candlestick bar data from `BTC/USD`
historical_prices = exchange.fetch_ohlcv("BTC/USD", "1d")

# Import the data as a Pandas DataFrame and set the columns
historical_prices_df = pd.DataFrame(
    historical_prices, columns=["timestamp", "open", "high", "low", "close", "volume"]
)
historical_prices_df
# Out:
#          timestamp    open    high     low   close       volume
# 0    1510704000000  6660.6  7300.0  6660.6  7260.0  7650.858383
# 1    1510790400000  7260.0  7790.0  7085.2  7750.7  8575.163873
# 2    1510876800000  7750.7  7950.0  7520.2  7695.7  5616.222294
# 3    1510963200000  7691.9  7849.9  7426.9  7786.0  2788.327685
# 4    1511049600000  7790.5  8000.0  7670.0  8000.0  2708.774322
# ..             ...     ...     ...     ...     ...          ...
# 715  1572480000000  9166.2  9459.7  8949.6  9146.7  4853.826649
# 716  1572566400000  9146.7  9323.4  9058.1  9258.9  3273.842285
# 717  1572652800000  9258.9  9392.0  9204.4  9303.6  2204.888657
# 718  1572739200000  9303.6  9383.7  9080.0  9209.3  1885.876149
# 719  1572825600000  9209.3  9338.0  9130.0  9313.0  1409.585534
#
# [720 rows x 6 columns]

# %% [markdown]
# ### Convert Epoch Timestamp to Readable Date Format

# %%
# Convert epoch timestamp to date using the `to_datetime` function and `unit` parameter
historical_prices_df["date"] = pd.to_datetime(
    historical_prices_df["timestamp"], unit="ms"
)
historical_prices_df.head()
# Out:
#        timestamp    open    high     low   close       volume       date
# 0  1510704000000  6660.6  7300.0  6660.6  7260.0  7650.858383 2017-11-15
# 1  1510790400000  7260.0  7790.0  7085.2  7750.7  8575.163873 2017-11-16
# 2  1510876800000  7750.7  7950.0  7520.2  7695.7  5616.222294 2017-11-17
# 3  1510963200000  7691.9  7849.9  7426.9  7786.0  2788.327685 2017-11-18
# 4  1511049600000  7790.5  8000.0  7670.0  8000.0  2708.774322 2017-11-19

# %% [markdown]
# ### Fetch Latest Data for BTC/USD

# %%
# Fetch current price details for `BTC/USD`
current_price = exchange.fetch_ticker('BTC/USD')

# Delete `info` key-value pair
del current_price['info']

current_price
# Out:
# {'symbol': 'BTC/USD',
#  'timestamp': 1572887447211,
#  'datetime': '2019-11-04T17:10:47.211Z',
#  'high': 9338.0,
#  'low': 9080.0,
#  'bid': 9311.0,
#  'bidVolume': None,
#  'ask': 9311.9,
#  'askVolume': None,
#  'vwap': 9209.42062,
#  'open': 9209.3,
#  'close': 9312.9,
#  'last': 9312.9,
#  'previousClose': None,
#  'change': None,
#  'percentage': None,
#  'average': None,
#  'baseVolume': 2207.54812486,
#  'quoteVolume': 20330239.22072802}

# %%
# Import data as a Pandas DataFrame
current_price_df = pd.DataFrame(current_price, index=[0])
current_price_df
# Out:
#     symbol      timestamp                  datetime    high     low     bid  \
# 0  BTC/USD  1572887447211  2019-11-04T17:10:47.211Z  9338.0  9080.0  9311.0
#
#   bidVolume     ask askVolume        vwap    open   close    last  \
# 0      None  9311.9      None  9209.42062  9209.3  9312.9  9312.9
#
#   previousClose change percentage average   baseVolume   quoteVolume
# 0          None   None       None    None  2207.548125  2.033024e+07

# %%
# Fetch balance
exchange.fetch_balance()
# Out:
# {'info': {}, 'free': {}, 'used': {}, 'total': {}}

# %%
# Fetch status
exchange.fetch_status()
# Out:
# {'status': 'ok', 'updated': None, 'eta': None, 'url': None}

# %%
# Fetch open orders
# exchange.fetch_open_orders()
