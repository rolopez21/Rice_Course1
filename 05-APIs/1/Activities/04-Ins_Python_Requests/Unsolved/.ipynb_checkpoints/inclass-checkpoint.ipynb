# %%
import requests
import json
import pandas as pd
from pprint import pprint

# %%
ticker = "MSFT"
url = f"https://www.quandl.com/api/v3/datasets/WIKI/{ticker}.json"

# %%
url
# Out:
# 'https://www.quandl.com/api/v3/datasets/WIKI/GOOG.json'

# %%
res = requests.get(url)

# %%
res
# Out:
# <Response [200]>

# %%
type(res.content)
# Out:
# bytes

# %%
ticker_data = res.json()

# %%
pprint(ticker_data)
# Out:
# {'dataset': {'collapse': None,
#              'column_index': None,
#              'column_names': ['Date',
#                               'Open',
#                               'High',
#                               'Low',
#                               'Close',
#                               'Volume',
#                               'Ex-Dividend',
#                               'Split Ratio',
#                               'Adj. Open',
#                               'Adj. High',
#                               'Adj. Low',
#                               'Adj. Close',
#                               'Adj. Volume'],
#              'data': [['2018-03-27',
#                        1063.0,
#                        1064.84,
#                        996.92,
#                        1005.1,
#                        3029471.0,
#                        0.0,
#                        1.0,
#                        1063.0,
#                        1064.84,
# ...

# %%
OHLC_columns = ticker_data["dataset"]["column_names"]
OHLC_data=ticker_data["dataset"]["data"]

# %%
pd.DataFrame(OHLC_data, columns=OHLC_columns)
# Out:
#             Date      Open       High        Low    Close     Volume  \
# 0     2018-03-27  1063.000  1064.8400   996.9200  1005.10  3029471.0
# 1     2018-03-26  1046.000  1055.6300  1008.4000  1053.21  2558385.0
# 2     2018-03-23  1047.030  1063.3600  1021.2200  1021.57  2113497.0
# 3     2018-03-22  1081.880  1082.9000  1045.9100  1049.08  2580374.0
# 4     2018-03-21  1092.740  1106.3000  1085.1500  1090.88  1640709.0
# 5     2018-03-20  1099.000  1105.2000  1083.4600  1097.71  1783872.0
# 6     2018-03-19  1120.010  1121.9900  1089.0100  1099.82  2339506.0
# 7     2018-03-16  1154.140  1155.8800  1131.9600  1135.73  2560277.0
# 8     2018-03-15  1149.960  1161.0800  1134.5400  1149.58  1392521.0
# 9     2018-03-14  1145.210  1158.5900  1141.4400  1149.49  1192615.0
# 10    2018-03-13  1170.000  1176.7600  1133.3300  1138.17  1808098.0
# 11    2018-03-12  1163.850  1177.0500  1157.4200  1164.50  2076306.0
# 12    2018-03-09  1136.000  1160.8000  1132.4600  1160.04  2074952.0
# ...

# %%
print(json.dumps(ticker_data, indent=4))
# Out:
# {
#     "dataset": {
#         "id": 9775718,
#         "dataset_code": "GOOG",
#         "database_code": "WIKI",
#         "name": "Alphabet Inc (GOOG) Prices, Dividends, Splits and Trading Volume",
#         "description": "End of day open, high, low, close and volume, dividends and splits, and split/dividend adjusted open, high, low close and volume for Google Inc. (GOOG). Ex-Dividend is non-zero on ex-dividend dates. Split Ratio is 1 on non-split dates. Adjusted prices are calculated per CRSP (www.crsp.com/products/documentation/crsp-calculations)\n\nThis data is in the public domain. You may copy, distribute, disseminate or include the data in other products for commercial and/or noncommercial purposes.\n\nThis data is part of Quandl's Wiki initiative to get financial data permanently into the public domain. Quandl relies on users like you to flag errors and provide data where data is wrong or missing. Get involved: connect@quandl.com\n",
# ...
