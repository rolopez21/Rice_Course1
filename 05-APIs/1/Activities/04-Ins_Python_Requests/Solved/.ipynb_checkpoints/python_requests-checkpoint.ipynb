# %%
import requests

# %%
# Create variable to hold request url
url = "http://api.worldbank.org/v2/country/all/indicator/NY.GDP.MKTP.CD"

# %%
# Add format specifier to request url
url = url + "?format=json"

# %% [markdown]
# ### Execute GET request with URL

# %%
# Execute get request
requests.get(url)
# Out:
# <Response [200]>

# %% [markdown]
# ### Store response as variable

# %%
# Execute GET request and store response
response_data = requests.get(url)

# %% [markdown]
# ### Retrieve API output using `content` attribute

# %%
# Get content
response_content = response_data.content
print(response_content)
# Out:
# b'[{"page":1,"pages":312,"per_page":50,"total":15576,"sourceid":"2","lastupdated":"2019-04-24"},[{"indicator":{"id":"NY.GDP.MKTP.CD","value":"GDP (current US$)"},"country":{"id":"1A","value":"Arab World"},"countryiso3code":"","date":"2018","value":null,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"NY.GDP.MKTP.CD","value":"GDP (current US$)"},"country":{"id":"1A","value":"Arab World"},"countryiso3code":"","date":"2017","value":2584531235434.03,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"NY.GDP.MKTP.CD","value":"GDP (current US$)"},"country":{"id":"1A","value":"Arab World"},"countryiso3code":"","date":"2016","value":2513129182099.64,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"NY.GDP.MKTP.CD","value":"GDP (current US$)"},"country":{"id":"1A","value":"Arab World"},"countryiso3code":"","date":"2015","value":2560770634365.22,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"NY.GDP.MKTP.CD","value":"GDP (current US$)"},"country":{"id":"1A","value":"Arab World"},"countryiso3code":"","date":"2014","value":2908394129857.66,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"NY.GDP.MKTP.CD","value":"GDP (current US$)"},"country":{"id":"1A","value":"Arab World"},"countryiso3code":"","date":"2013","value":2866861303189.56,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"NY.GDP.MKTP.CD","value":"GDP (current US$)"},"country":{"id":"1A","value":"Arab World"},"countryiso3code":"","date":"2012","value":2786787184920.6,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"NY.GDP.MKTP.CD","value":"GDP (current US$)"},"country":{"id":"1A","value":"Arab World"},"countryiso3code":"","date":"2011","value":2501738923095.22,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"NY.GDP.MKTP.CD","value":"GDP (current US$)"},"country":{"id":"1A","value":"Arab World"},"countryiso3code":"","date":"2010","value":2109932335481.52,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"NY.GDP.MKTP.CD","value":"GDP (current US$)"},"country":{"id":"1A","value":"Arab World"},"countryiso3code":"","date":"2009","value":1796199871252.04,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"NY.GDP.MKTP.CD","value":"GDP (current US$)"},"country":{"id":"1A","value":"Arab World"},"countryiso3code":"","date":"2008","value":2078570170452.08,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"NY.GDP.MKTP.CD","value":"GDP (current US$)"},"country":{"id":"1A","value":"Arab World"},"countryiso3code":"","date":"2007","value":1638213879955.77,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"NY.GDP.MKTP.CD","value":"GDP (current US$)"},"country":{"id":"1A","value":"Arab World"},"countryiso3code":"","date":"2006","value":1404653310998.68,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"NY.GDP.MKTP.CD","value":"GDP (current US$)"},"country":{"id":"1A","value":"Arab World"},"countryiso3code":"","date":"2005","value":1185142919458.18,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"NY.GDP.MKTP.CD","value":"GDP (current US$)"},"country":{"id":"1A","value":"Arab World"},"countryiso3code":"","date":"2004","value":964327345387.531,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"NY.GDP.MKTP.CD","value":"GDP (current US$)"},"country":{"id":"1A","value":"Arab World"},"countryiso3code":"","date":"2003","value":823341300650.195,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"NY.GDP.MKTP.CD","value":"GDP (current US$)"},"country":{"id":"1A","value":"Arab World"},"countryiso3code":"","date":"2002","value":729231446595.318,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"NY.GDP.MKTP.CD","value":"GDP (current US$)"},"country":{"id":"1A","value":"Arab World"},"countryiso3code":"","date":"2001","value":723449066469.795,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"NY.GDP.MKTP.CD","value":"GDP (current US$)"},"country":{"id":"1A","value":"Arab World"},"countryiso3code":"","date":"2000","value":735188056517.167,"unit":"","obs_status" ...

# %% [markdown]
# ### Use `json` function from `json` library to format

# %%
import json

# Formatting as json
data = response_data.json()

# %% [markdown]
# ### Format JSON with indents

# %%
# Add indents to JSON and output to screen
print(json.dumps(data, indent=4))
# Out:
# [
#     {
#         "page": 1,
#         "pages": 312,
#         "per_page": 50,
#         "total": 15576,
#         "sourceid": "2",
#         "lastupdated": "2019-04-24"
#     },
#     [
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "",
#             "date": "2018",
#             "value": null,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "",
#             "date": "2017",
#             "value": 2584531235434.03,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "",
#             "date": "2016",
#             "value": 2513129182099.64,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "",
#             "date": "2015",
#             "value": 2560770634365.22,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "",
#             "date": "2014",
#             "value": 2908394129857.66,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "",
#             "date": "2013",
#             "value": 2866861303189.56,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "",
#             "date": "2012",
#             "value": 2786787184920.6,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "",
#             "date": "2011",
#             "value": 2501738923095.22,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "",
#             "date": "2010",
#             "value": 2109932335481.52,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "",
#             "date": "2009",
#             "value": 1796199871252.04,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "",
#             "date": "2008",
#             "value": 2078570170452.08,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "",
#             "date": "2007",
#             "value": 1638213879955.77,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "",
#             "date": "2006",
#             "value": 1404653310998.68,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "",
#             "date": "2005",
#             "value": 1185142919458.18,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "",
#             "date": "2004",
#             "value": 964327345387.531,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "",
#             "date": "2003",
#             "value": 823341300650.195,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "",
#             "date": "2002",
#             "value": 729231446595.318,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "",
#             "date": "2001",
#             "value": 723449066469.795,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "",
#             "date": "2000",
#             "value": 735188056517.167,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "",
#             "date": "1999",
#             "value": 644050661585.064,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "",
#             "date": "1998",
#             "value": 591681589857.127,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "",
#             "date": "1997",
#             "value": 613432360792.61,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "",
#             "date": "1996",
#             "value": 578398811758.025,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "",
#             "date": "1995",
#             "value": 523928956600.448,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "",
#             "date": "1994",
#             "value": 487661715245.43,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "",
#             "date": "1993",
#             "value": 477133962042.005,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "",
#             "date": "1992",
#             "value": 471671634103.682,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "",
#             "date": "1991",
#             "value": 440649432072.993,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "",
#             "date": "1990",
#             "value": 446901684405.475,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "",
#             "date": "1989",
#             "value": 322523097140.702,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "",
#             "date": "1988",
#             "value": 307570926002.98,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "",
#             "date": "1987",
#             "value": 312752951185.987,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "",
#             "date": "1986",
#             "value": 293367374486.247,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "",
#             "date": "1985",
#             "value": 307407291560.648,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "",
#             "date": "1984",
#             "value": 310632323085.707,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "",
#             "date": "1983",
#             "value": 306261791758.792,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "",
#             "date": "1982",
#             "value": 326020360664.888,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "",
#             "date": "1981",
#             "value": 347656118407.864,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "",
#             "date": "1980",
#             "value": 338248771411.72,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "",
#             "date": "1979",
#             "value": 248595600128.175,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "",
#             "date": "1978",
#             "value": 183563837139.041,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "",
#             "date": "1977",
#             "value": 167156343957.551,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "",
#             "date": "1976",
#             "value": 144841302607.404,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "",
#             "date": "1975",
#             "value": 116516174253.32,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "",
#             "date": "1974",
#             "value": 105341592850.765,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "",
#             "date": "1973",
#             "value": 55448298103.8347,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "",
#             "date": "1972",
#             "value": 43792913097.7755,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "",
#             "date": "1971",
#             "value": 36733034967.561,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "",
#             "date": "1970",
#             "value": 31705853030.0283,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "1A",
#                 "value": "Arab World"
#             },
#             "countryiso3code": "",
#             "date": "1969",
#             "value": 28132432225.1838,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         }
#     ]
# ]

# %% [markdown]
# ### Identify country and GDP value for first row

# %%
# Select country and GDP value for first row
country = data[1][1]['country']['value']
gdp_value = data[1][1]['value']

print("Country: " + country)
print("GDP Value: " + str(gdp_value))
# Out:
# Country: Arab World
# GDP Value: 2584531235434.03
