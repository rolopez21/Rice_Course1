# %% [markdown]
# ### Instructor Demo: Free Throw Simulation
#
# This program executes `1000` simulations for shooting `10` free throws, with a player having a `70%` chance of making the shot. Results are then saved to a DataFrame to calculate the frequency distribution and corresponding probability distribution of potentially made baskets.

# %%
# Import libraries and dependencies

# %% [markdown]
# ### Perform the Monte Carlo Simulation and Create Pandas DataFrame From Results

# %%
# Set number of simulations and free throws


# Set a list object acting as a throw: made basket or missed basket


# Set probability of events


# Create an empty DataFrame to hold simulation results


# Run n number of simulations


    # Print simulation iteration

    
    # Set an empty list to hold throw results


    # Shoot the ball `10` times

        
        # Randomly choose between `made` and `missed` with a `70%` chance to make the throw and a `30%` chance the throw is missed

        
        # Print throw result


        # Append throw result to list


    # Append column for each simulation and throw results


# Print the DataFrame
# Out:
#   Simulation 0 Simulation 1 Simulation 2 Simulation 3 Simulation 4  \
# 0         made       missed         made         made         made
# 1       missed         made       missed         made         made
# 2         made         made       missed         made         made
# 3       missed         made         made         made         made
# 4         made         made         made         made         made
# 5       missed         made         made       missed       missed
# 6       missed         made         made         made         made
# 7         made         made       missed       missed       missed
# 8         made         made         made       missed         made
# 9         made         made       missed         made         made
#
#   Simulation 5 Simulation 6 Simulation 7 Simulation 8 Simulation 9  ...  \
# 0         made         made       missed         made       missed  ...
# 1         made       missed         made         made         made  ...
# 2         made         made         made         made         made  ...
# 3         made       missed       missed         made       missed  ...
# 4         made       missed       missed         made         made  ...
# 5         made       missed         made         made       missed  ...
# 6         made         made         made         made         made  ...
# 7         made         made       missed         made         made  ...
# 8         made         made         made         made         made  ...
# 9       missed         made         made         made         made  ...
#
#   Simulation 990 Simulation 991 Simulation 992 Simulation 993 Simulation 994  \
# 0           made           made           made           made           made
# 1         missed         missed         missed           made           made
# 2           made           made         missed         missed           made
# 3           made           made           made           made           made
# 4         missed         missed           made           made           made
# 5         missed           made           made           made           made
# 6           made           made           made           made         missed
# 7           made           made         missed           made           made
# 8         missed           made           made           made         missed
# 9         missed           made           made           made         missed
#
#   Simulation 995 Simulation 996 Simulation 997 Simulation 998 Simulation 999
# 0           made           made           made           made           made
# 1           made         missed           made           made           made
# 2           made         missed           made           made         missed
# 3           made           made           made           made         missed
# 4         missed           made           made         missed           made
# 5           made           made           made           made           made
# 6           made           made           made           made         missed
# 7           made         missed         missed           made           made
# 8         missed           made         missed           made           made
# 9           made           made           made           made         missed
#
# [10 rows x 1000 columns]

# %% [markdown]
# ### Calculate Frequency Distribution of Made-to-Missed Throws for 1000 Simulations of 10 Free Throws and Save Results to DataFrame

# %%
# Set empty DataFrame to hold frequency distribution values


# Set empty lists to hold made throws and missed throws results per simulation


# Loop through the results of every simulation

    
    # Use the `value_counts` function to calculate the frequency distribution 
    # of made-to-missed throws for every simulation, returns Series object

    
    # Append results of made and missed throws to respective lists
    # If `made` and `missed key is present in the Series, append both results

        
    # If `made` key is not present in the Series, append made throw list with 0
    # And append missed throw list with missed result (simulation must have returned all missed throws)

        
    # If `missed` key is not present in the Series, append missed throw list with 0
    # And append made throws list with made result (simulation must have returned all made throws)

        
# Create columns from heads and tails lists
# Out:
#    made_throws  missed_throws
# 0            6              4
# 1            9              1
# 2            6              4
# 3            7              3
# 4            8              2

# %% [markdown]
# ### Plot Frequency Distribution of Made Free Throws for 1000 Simulations of 10 Free Throws

# %%
# Plot the data as a histogram

# %%
# Plot the data as a histogram but manually set the bin ranges

# %% [markdown]
# ### Plot Probability Distribution of Made Free Throws for 1000 Simulations of 10 Free Throws

# %%
# Plot the data as a histogram with probabilities of

# %% [markdown]
# ### What is the Likelihood That the Player Makes `9-10` Free Throws in a Single Session?

# %% [markdown]
# Based on the probability distribution of made free throws for the player, it would appear as though the likelihood of the player making `9-10` free throws in a single session is approximately `15%`.
