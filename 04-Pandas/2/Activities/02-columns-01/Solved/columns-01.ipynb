# %% [markdown]
# # Column Manipulation of Pandas DataFrames

# %% [markdown]
# ### 1. Import libraries and dependencies

# %%
# Import pandas, pathlib, and numpy libraries
import pandas as pd
from pathlib import Path
import numpy as np

# %% [markdown]
# ### 2. Create a Path to the File Using Pathlib

# %%
# Use the Pathlib libary to set the path to the CSV
csvpath = Path("../Resources/people.csv")

# %% [markdown]
# ### 3. Read the CSV into a Pandas DataFrame and Display a Few Rows

# %%
# Use the file path to read the CSV into a DataFrame and display a few rows
people_df = pd.read_csv(csvpath)
people_df.head()
# Out:
#     id first_name    last_name                            email  gender  \
# 0  1.0    Keriann    Lenormand  klenormand0@businessinsider.com  Female
# 1  2.0    Huntley        Rupke              hrupke1@reuters.com    Male
# 2  3.0     Gorden  Dalgarnowch      gdalgarnowch2@microsoft.com    Male
# 3  4.0     Cullie          NaN               cputten3@nymag.com    Male
# 4  5.0      Ariel    Strangman       astrangman4@bravesites.com  Female
#
#                                             uni_grad           job_title  \
# 0                                  Aurora University  Nurse Practicioner
# 1                      Osaka University of Economics     Project Manager
# 2                                  Ludong University  Environmental Tech
# 3  Université des Sciences et de la Technologie d...     Legal Assistant
# 4                             Boise State University     Project Manager
#
#     Income
# 0  58135.0
# 1  96053.0
# 2  59196.0
# 3  88493.0
# 4  89073.0

# %% [markdown]
# ### 4. View Columns Names

# %%
# Use the `columns` attribute to output the column names
people_df.columns
# Out:
# Index(['id', 'first_name', 'last_name', 'email', 'gender', 'uni_grad',
#        'job_title', 'Income'],
#       dtype='object')

# %% [markdown]
# ### 5. View Column Data Types

# %%
# Use the `dtypes` attribute to output the column names and data types
people_df.dtypes
# Out:
# id            float64
# first_name     object
# last_name      object
# email          object
# gender         object
# uni_grad       object
# job_title      object
# Income        float64
# dtype: object

# %% [markdown]
# ### 6. Rename Columns Using List

# %%
# Set the `columns` attribute to a new list of column names
columns = ["Person_ID", "First_Name", "Last_Name", "Email", "Gender", "University", "Occupation", "Salary"]
people_df.columns = columns
people_df.head()
# Out:
#    Person_ID First_Name    Last_Name                            Email  Gender  \
# 0        1.0    Keriann    Lenormand  klenormand0@businessinsider.com  Female
# 1        2.0    Huntley        Rupke              hrupke1@reuters.com    Male
# 2        3.0     Gorden  Dalgarnowch      gdalgarnowch2@microsoft.com    Male
# 3        4.0     Cullie          NaN               cputten3@nymag.com    Male
# 4        5.0      Ariel    Strangman       astrangman4@bravesites.com  Female
#
#                                           University          Occupation  \
# 0                                  Aurora University  Nurse Practicioner
# 1                      Osaka University of Economics     Project Manager
# 2                                  Ludong University  Environmental Tech
# 3  Université des Sciences et de la Technologie d...     Legal Assistant
# 4                             Boise State University     Project Manager
#
#     Salary
# 0  58135.0
# 1  96053.0
# 2  59196.0
# 3  88493.0
# 4  89073.0

# %% [markdown]
# ### 7. Rename Columns Using Dictionary

# %%
# Use the `rename` function and set the `columns` parameter to a dictionary of new column names
people_df = people_df.rename(columns={
    "id": "Person_ID",
    "first_name": "First_Name",
    "last_name": "Last_Name", 
    "email": "Email",
    "gender": "Gender",
    "uni_grad": "University_Grad",
    "job_title": "Occupation",
    "Income": "Salary"
})

people_df.head()
# Out:
#    Person_ID First_Name    Last_Name                            Email  Gender  \
# 0        1.0    Keriann    Lenormand  klenormand0@businessinsider.com  Female
# 1        2.0    Huntley        Rupke              hrupke1@reuters.com    Male
# 2        3.0     Gorden  Dalgarnowch      gdalgarnowch2@microsoft.com    Male
# 3        4.0     Cullie          NaN               cputten3@nymag.com    Male
# 4        5.0      Ariel    Strangman       astrangman4@bravesites.com  Female
#
#                                           University          Occupation  \
# 0                                  Aurora University  Nurse Practicioner
# 1                      Osaka University of Economics     Project Manager
# 2                                  Ludong University  Environmental Tech
# 3  Université des Sciences et de la Technologie d...     Legal Assistant
# 4                             Boise State University     Project Manager
#
#     Salary
# 0  58135.0
# 1  96053.0
# 2  59196.0
# 3  88493.0
# 4  89073.0

# %% [markdown]
# ### 8. Re-order Columns

# %%
people_df[people_df["Person_ID"]>40]
# people_df.sort_values("Salary")
# Out:
#      Person_ID  First_Name     Last_Name                               Email  \
# 40        41.0    Gilberto       Trulock            gtrulock14@google.com.hk
# 41        42.0    Horatius        Reilly                  hreilly15@bing.com
# 42        43.0        Kati      Dodgshun                  kdodgshun16@i2i.jp
# 43        44.0      Jillie        Bickle       jbickle17@cargocollective.com
# 44        45.0      Hadlee       Jenicek              hjenicek18@histats.com
# 45        46.0         Eba      MacCague            emaccague19@omniture.com
# 46        47.0       Darya        Pettie               dpettie1a@walmart.com
# 47        48.0      Edmund        Tupper                   etupper1b@ted.com
# 48        49.0    Fredrick        Angove             fangove1c@newyorker.com
# 49        50.0     Gabrila      Semeniuk             gsemeniuk1d@harvard.edu
# 50        51.0     Rollins        Edards                 redards1e@unblog.fr
# 51        52.0       Lilah         Ewens                  lewens1f@weibo.com
# 52        53.0      Ronica       Gowling              rgowling1g@weather.com
# 53        54.0      Mollie          Orht                  morht1h@usnews.com
# 54        55.0     Melinde         Novic            mnovic1i@accuweather.com
# 55        56.0      Jolene       Le Barr                jlebarr1j@census.gov
# 56        57.0     Monique        Fogden                 mfogden1k@opera.com
# 57        58.0     Zebulon     Josefovic            zjosefovic1l@pcworld.com
# 58        59.0        Zerk      Goulston           zgoulston1m@artisteer.com
# 59        60.0      Dyanne       Ogborne                  dogborne1n@wix.com
# 60        61.0       Denny     Yearnsley           dyearnsley1o@blogspot.com
# 61        62.0       Sadie         Extil                       sextil1p@g.co
# 62        63.0     Kalindi       Chasson             kchasson1q@symantec.com
# 63        64.0       Betty       Witnall                bwitnall1r@nymag.com
# 64        65.0      Rosene       Rottery                rrottery1s@yandex.ru
# 65        66.0        Jeri    Kennington             jkennington1t@upenn.edu
# 66        67.0      Sybila       Chauvey              schauvey1u@vinaora.com
# 67        68.0      Jeanna   Giovannacci         jgiovannacci1v@usatoday.com
# 68        69.0       Ozzie       Penfold               openfold1w@oracle.com
# 69        70.0      Mathew         Gregg             mgregg1x@shutterfly.com
# ..         ...         ...           ...                                 ...
# 970      971.0       Ennis      Perchard             eperchardqy@storify.com
# 971      972.0      Sigrid      Attfield  sattfieldqz@nationalgeographic.com
# 972      973.0       Kathi       Spurdle                 kspurdler0@ucla.edu
# 973      974.0     Antonio    Haspineall    ahaspineallr1@simplemachines.org
# 974      975.0   Bernadina     Shoveller                 bshovellerr2@ca.gov
# 975      976.0      Nanete       Pickett         npickettr3@businesswire.com
# 976      977.0      Hastie      Lethbrig               hlethbrigr4@europa.eu
# 977      978.0      Danice   McPhillimey           dmcphillimeyr5@flickr.com
# 978      979.0        Kale     Yurchenko           kyurchenkor6@netscape.com
# 979      980.0      Dillon         Eykel          deykelr7@independent.co.uk
# 980      981.0       Alley        Tarbox               atarboxr8@comcast.net
# 981      982.0       Nydia     Cocksedge                 ncocksedger9@goo.gl
# 982      983.0       Dayna    Boutellier            dboutellierra@tumblr.com
# 983      984.0       Angie       Maharey                   amahareyrb@w3.org
# 984      985.0      Felice  Strongitharm              fstrongitharmrc@pen.io
# 985      986.0     Humbert         Grint              hgrintrd@google.com.br
# 986      987.0        Kaye       Morratt                kmorrattre@youku.com
# 987      988.0      Jillie     Karolczyk              jkarolczykrf@unblog.fr
# 988      989.0  Estrellita         Waker              ewakerrg@angelfire.com
# 989      990.0       Urson           NaN                 uenrdigorh@gmpg.org
# 990      991.0      Julian     Hampshire             jhampshireri@disqus.com
# 991      992.0      Davine       Glossop            dglossoprj@goodreads.com
# 992      993.0    Dorothea          Rugg            druggrk@miitbeian.gov.cn
# 993      994.0     Damaris     Griffitts           dgriffittsrl@mapquest.com
# 994      995.0        Iggy        Jeacop               ijeacoprm@4shared.com
# 995      996.0        Meta      Crumpton                  mcrumptonrn@qq.com
# 996      997.0       Gunar       Gilford                ggilfordro@yandex.ru
# 997      998.0    Lucretia       Gurling                    lgurlingrp@de.vu
# 998      999.0      Andrew          Yang                ayang@codedrills.com
# 999     1000.0      Andrew          Yang                ayang@codedrills.com
#
#      Gender                                         University  \
# 40     Male  Universidad Centroamericana de Ciencias Empres...
# 41     Male  Preston Institute of Management Sciences and T...
# 42   Female  Rivers State University of Science and Technology
# 43   Female      University of Insurance and Banking in Warsaw
# 44     Male                                 Krishna University
# 45   Female                        Toin University of Yokohama
# 46   Female                  Instituto Universitario de La Paz
# 47     Male                   Hokkaido University of Education
# 48     Male                              Bahcesehir University
# 49   Female                       Changwon National University
# 50     Male                         Jaipur National University
# 51   Female             Bidhan Chandra Agricultural University
# 52   Female              Minneapolis College of Art and Design
# 53   Female                                     Wilson College
# 54   Female                           Majan University College
# 55   Female                                Langston University
# 56   Female  Guangzhou University of Traditional Chinese Me...
# 57     Male                            Rajiv Gandhi University
# 58     Male              Universidad Tecnologica de la Mixteca
# 59   Female                            Nara Medical University
# 60   Female                                 Seton Hill College
# 61   Female                             Kurukshetra University
# 62   Female                                 Universität Kassel
# 63   Female                                     Midway College
# 64   Female  Universidad Internacional de Andalucía, Sede A...
# 65   Female                                  Assosa University
# 66   Female                                 Beykent University
# 67   Female                       Olabisi Onabanjo University
# 68     Male                                    Saga University
# 69     Male                     Korea National Open University
# ..      ...                                                ...
# 970    Male                               University of Exeter
# 971  Female                            Universidad de La Salle
# 972  Female                       United States Sports Academy
# 973    Male                              Lansbridge University
# 974  Female                        Midwestern State University
# 975  Female  Ecole Nationale Supérieure de Physique de Gren...
# 976    Male                                Ecole Polytechnique
# 977  Female                                Université d'Artois
# 978    Male                Southeast Missouri State University
# 979    Male                                    Shorter College
# 980    Male                      University of Alaska (System)
# 981  Female                              University of Wroclaw
# 982  Female                                   Ummah University
# 983  Female                              Utsunomiya University
# 984    Male  University of Engineering and Technology Peshawar
# 985    Male  National Technical University (Kharkiv Polytec...
# 986  Female  Shaheed Zulifkar Ali Bhutto Institute of Scien...
# 987  Female                                 Providence College
# 988  Female                                New England College
# 989    Male                             Wilberforce University
# 990    Male                         Johnson & Wales University
# 991  Female                Université René Descartes (Paris V)
# 992  Female             Universidad Politécnica de El Salvador
# 993  Female                             The College of Wooster
# 994    Male                            University of Greenwich
# 995  Female               ECAM - Institut Supérieur Industriel
# 996    Male                                  Smolny University
# 997  Female                          Institut Teknologi Telkom
# 998    Male              Rutgers University School of Business
# 999    Male              Rutgers University School of Business
#
#                        Occupation    Salary
# 40     Desktop Support Technician   50013.0
# 41       Systems Administrator II  108483.0
# 42                Legal Assistant   70565.0
# 43                       Operator  116522.0
# 44          VP Product Management   90837.0
# 45               Graphic Designer   90212.0
# 46             Environmental Tech   57954.0
# 47          VP Product Management  112162.0
# 48     Desktop Support Technician   83617.0
# 49          Programmer Analyst II   94271.0
# 50              Account Executive   71449.0
# 51                 Tax Accountant   51255.0
# 52     Software Test Engineer III   67941.0
# 53           Compensation Analyst  103995.0
# 54             Speech Pathologist   93086.0
# 55             Environmental Tech   53559.0
# 56                   Geologist II   91214.0
# 57            Staff Accountant IV   82462.0
# 58   Budget/Accounting Analyst II   71428.0
# 59              Account Executive   88929.0
# 60               Senior Developer   98678.0
# 61                        Teacher  112379.0
# 62          Programmer Analyst IV  117041.0
# 63   Human Resources Assistant IV  111961.0
# 64                  VP Accounting   66149.0
# 65             Analyst Programmer   81498.0
# 66             Speech Pathologist   59743.0
# 67             Help Desk Operator  103759.0
# 68                      Librarian   96074.0
# 69               Internal Auditor   69038.0
# ..                            ...       ...
# 970        Accounting Assistant I  109716.0
# 971       Senior Quality Engineer   93769.0
# 972                  VP Marketing   56669.0
# 973               Legal Assistant   71608.0
# 974             Assistant Manager   63355.0
# 975       Human Resources Manager  108835.0
# 976           Electrical Engineer   73842.0
# 977      Automation Specialist II   71578.0
# 978            Biostatistician IV   54576.0
# 979                    Pharmacist  110623.0
# 980            Speech Pathologist   91118.0
# 981              Quality Engineer   63085.0
# 982           Software Engineer I   70141.0
# 983                  Accountant I   65560.0
# 984                       Actuary   60366.0
# 985             Financial Analyst  114068.0
# 986        Senior Sales Associate   82362.0
# 987              Dental Hygienist   52966.0
# 988      Database Administrator I   80118.0
# 989                     Librarian   79603.0
# 990             Chemical Engineer   79024.0
# 991            VP Quality Control   50599.0
# 992                  VP Marketing  114586.0
# 993                 Senior Editor  113339.0
# 994               Sales Associate   82726.0
# 995              Registered Nurse   57060.0
# 996             Marketing Manager   76109.0
# 997         Software Engineer III   92115.0
# 998           Curriculum Engineer   60000.0
# 999           Curriculum Engineer   60000.0
#
# [956 rows x 8 columns]

# %%
# Use a list of re-ordered column names to alter the column order of the original DataFrame
people_df = people_df[["Person_ID", "Last_Name", "First_Name", "Gender", "University", "Occupation", "Salary", "Email"]]
people_df.head()
# Out:
#    Person_ID    Last_Name First_Name  Gender  \
# 0        1.0    Lenormand    Keriann  Female
# 1        2.0        Rupke    Huntley    Male
# 2        3.0  Dalgarnowch     Gorden    Male
# 3        4.0       Putten     Cullie    Male
# 4        5.0    Strangman      Ariel  Female
#
#                                           University          Occupation  \
# 0                                  Aurora University  Nurse Practicioner
# 1                      Osaka University of Economics     Project Manager
# 2                                  Ludong University  Environmental Tech
# 3  Université des Sciences et de la Technologie d...     Legal Assistant
# 4                             Boise State University     Project Manager
#
#     Salary                            Email
# 0  58135.0  klenormand0@businessinsider.com
# 1  96053.0              hrupke1@reuters.com
# 2  59196.0      gdalgarnowch2@microsoft.com
# 3  88493.0               cputten3@nymag.com
# 4  89073.0       astrangman4@bravesites.com

# %% [markdown]
# ### 9. Create Additional Column

# %%
# Use the `randint` function to randomly generate an `Age` from 22 to 65 for 1000 rows
people_df["Age"] = np.random.randint(low=22, high=65, size=1000)
people_df["Age_Copy"] = np.random.randint(low=22, high=65, size=1000)
people_df.head()
# Out:
#    Person_ID    Last_Name First_Name  Gender  \
# 0        1.0    Lenormand    Keriann  Female
# 1        2.0        Rupke    Huntley    Male
# 2        3.0  Dalgarnowch     Gorden    Male
# 3        4.0       Putten     Cullie    Male
# 4        5.0    Strangman      Ariel  Female
#
#                                           University          Occupation  \
# 0                                  Aurora University  Nurse Practicioner
# 1                      Osaka University of Economics     Project Manager
# 2                                  Ludong University  Environmental Tech
# 3  Université des Sciences et de la Technologie d...     Legal Assistant
# 4                             Boise State University     Project Manager
#
#     Salary                            Email  Age  Age_Copy
# 0  58135.0  klenormand0@businessinsider.com   27        42
# 1  96053.0              hrupke1@reuters.com   22        51
# 2  59196.0      gdalgarnowch2@microsoft.com   40        43
# 3  88493.0               cputten3@nymag.com   62        56
# 4  89073.0       astrangman4@bravesites.com   47        45

# %% [markdown]
# ### 10. Delete Columns

# %%
people_df.dtypes
# Out:
# Person_ID     float64
# First_Name     object
# Last_Name      object
# Email          object
# Gender         object
# University     object
# Occupation     object
# Salary        float64
# dtype: object

# %%
# Use the `drop` function to delete the newly created `Age` column
people_df = people_df.drop(columns=["First_Name"])
people_df.head()
# Out:
#    Person_ID    Last_Name                            Email  Gender  \
# 0        1.0    Lenormand  klenormand0@businessinsider.com  Female
# 1        2.0        Rupke              hrupke1@reuters.com    Male
# 2        3.0  Dalgarnowch      gdalgarnowch2@microsoft.com    Male
# 3        4.0          NaN               cputten3@nymag.com    Male
# 4        5.0    Strangman       astrangman4@bravesites.com  Female
#
#                                           University          Occupation  \
# 0                                  Aurora University  Nurse Practicioner
# 1                      Osaka University of Economics     Project Manager
# 2                                  Ludong University  Environmental Tech
# 3  Université des Sciences et de la Technologie d...     Legal Assistant
# 4                             Boise State University     Project Manager
#
#     Salary
# 0  58135.0
# 1  96053.0
# 2  59196.0
# 3  88493.0
# 4  89073.0

# %% [markdown]
# ### 11. Save Modified DataFrame to New CSV

# %%
# Save the DataFrame to the `Resources` folder
people_df.to_csv("../Resources/people_reordered.csv")
