# %% [markdown]
# ### Instructor Demo: Probable Outcomes of Stock Price Trajectory
#
# This program executes `1000` simulations of stock price trajectory over the next `252` trading days (or year of trading), based on a normal probability distribution of average daily returns derived from the sample mean and standard deviation.

# %%
# Import libraries and dependencies

# %% [markdown]
# ### Check Available Tickers from IEX Cloud API

# %%
# Return available tickers from API
# Out:
#          date  iexId  isEnabled                       name symbol type
# 0  2019-06-10      2       True  Agilent Technologies Inc.      A   cs
# 1  2019-06-10  12042       True          Alcoa Corporation     AA   cs
# 2  2019-06-10  14924       True   Perth Mint Physical Gold   AAAU  N/A
# 3  2019-06-10   7653       True                Altaba Inc.   AABA   cs
# 4  2019-06-10   9169       True          AAC Holdings Inc.    AAC   cs

# %% [markdown]
# ### Get 1 Year's Worth of Data via API Call and Read in as DataFrame

# %%
# Set the ticker


# Set start and end datetimes of 1 year, between now and 365 days ago.


# Get 1 year's worth of historical data for AAPL
# Out:
#                 open      high       low     close    volume
# date
# 2018-06-11  188.4809  189.0916  187.3580  188.3627  18308460
# 2018-06-12  188.5153  189.7230  188.2839  189.3969  16911141
# 2018-06-13  189.5348  189.9879  187.5845  187.8406  21638393
# 2018-06-14  188.6779  188.6976  187.3678  187.9391  21610074
# 2018-06-15  187.1807  187.3087  185.4372  186.0085  61719160

# %% [markdown]
# ### Drop Extraneous Columns

# %%
# Use the `drop` function to drop extra columns in the DataFrame
# Out:
#                close
# date
# 2018-06-11  188.3627
# 2018-06-12  189.3969
# 2018-06-13  187.8406
# 2018-06-14  187.9391
# 2018-06-15  186.0085

# %% [markdown]
# ### Calculate Daily Returns

# %%
# Use the `pct_change` function to calculate daily returns of AAPL
# Out:
#                close
# date
# 2018-06-11       NaN
# 2018-06-12  0.005490
# 2018-06-13 -0.008217
# 2018-06-14  0.000524
# 2018-06-15 -0.010272

# %% [markdown]
# ### Calculate Value of Average Daily Returns

# %%
# Use the `mean` function to calculate the mean of daily returns for AAPL
# Out:
# 0.00022986055125439583

# %% [markdown]
# ### Calculate Value of Standard Deviation of Daily Returns

# %%
# Use the `std` function to calculate the standard deviation of daily returns for AAPL
# Out:
# 0.019563747524048596

# %% [markdown]
# ### Run the Monte Carlo Simulation and Save Results to DataFrame

# %%
# Set number of simulations, trading days, and get last closing price of AAPL from DataFrame


# Initialize empty DataFrame to hold simulated prices for each simulation


# Run the simulation of projecting stock prices for the next trading year, `1000` times


    # Initialize the simulated prices list with the last closing price of AAPL

    
    # Simulate the returns for 252 days

        # Calculate the simulated price using the last price within the list

        # Append the simulated price to the list

    
    # Append a simulated prices of each simulation to DataFrame


# Print head of DataFrame
# Out:
#    Simulation 1  Simulation 2  Simulation 3  Simulation 4  Simulation 5  \
# 0    190.150000    190.150000    190.150000    190.150000    190.150000
# 1    187.736811    184.203871    185.437694    189.393759    190.756382
# 2    185.724180    181.841180    182.017148    191.574346    195.208695
# 3    187.627606    183.654146    176.159663    191.549876    197.771148
# 4    186.838252    185.471081    175.401099    195.167248    199.853162
#
#    Simulation 6  Simulation 7  Simulation 8  Simulation 9  Simulation 10  ...  \
# 0    190.150000    190.150000    190.150000    190.150000     190.150000  ...
# 1    188.733806    189.190426    188.253537    187.867401     185.006253  ...
# 2    185.305713    189.701186    186.281182    187.183012     180.391521  ...
# 3    182.422006    194.462152    185.288733    189.254590     180.613190  ...
# 4    176.913988    194.359576    185.502599    194.739626     177.845296  ...
#
#    Simulation 991  Simulation 992  Simulation 993  Simulation 994  \
# 0      190.150000      190.150000      190.150000      190.150000
# 1      193.441266      191.382524      187.865525      187.929701
# 2      196.274453      190.938121      188.855383      191.194078
# 3      196.210981      189.459535      181.841958      192.274713
# 4      193.137121      188.559274      179.189760      192.167198
#
#    Simulation 995  Simulation 996  Simulation 997  Simulation 998  \
# 0      190.150000      190.150000      190.150000      190.150000
# 1      197.468567      190.929465      186.190454      191.283917
# 2      201.816518      192.178066      188.005373      195.155826
# 3      201.202302      189.712122      186.439426      191.020040
# 4      204.327617      193.756028      186.857988      191.478676
#
#    Simulation 999  Simulation 1000
# 0      190.150000       190.150000
# 1      192.027876       191.232824
# 2      190.575567       193.023298
# 3      197.712512       198.104679
# 4      198.006126       203.591590
#
# [5 rows x 1000 columns]

# %% [markdown]
# ### Plot the Multiple Simulations of Stock Price Trajectory for AAPL over the Next Year (252 Trading Days)

# %%
# Use the `plot` function to plot the trajectory of AAPL stock based on a 252 trading day simulation

# %%
# Select the last row for project stock prices (prices of each simulation on the 252nd trading day)
# Out:
# Simulation 1    252.040644
# Simulation 2    137.031477
# Simulation 3    161.093349
# Simulation 4    326.372434
# Simulation 5    171.297080
# Name: 252, dtype: float64

# %% [markdown]
# ### Plot the Frequency Distribution of Simulated Ending Prices on 252nd Trading Day

# %%
# Use the `plot` function to plot a frequency distribution of simulated ending prices

# %% [markdown]
# ### Calculate Lower and Upper Bounds of 95% Confidence Interval for Simulated Ending Stock Prices of AAPL

# %%
# Use the `quantile` function to calculate the 95% confidence interval for simulated ending prices
# Out:
# 0.025    106.224189
# 0.975    329.273376
# Name: 252, dtype: float64

# %% [markdown]
# ### Plot the Probability Distribution and 95% Confidence Interval of Simulated Ending Prices

# %%
# Use the `plot` function to create a probability distribution histogram of simulated ending prices
# with markings for a 95% confidence interval

# %% [markdown]
# ### Calculate 95% Confidence Interval of An Initial Investment of 10,000 in AAPL over the Next 252 Trading Days

# %%
# Set initial investment


# Calculate cumulative profit/loss of lower and upper bound


# Add the initial investment to the cumulative profit/loss of lower and upper bound


# Print the results
# Out:
# There is a 95% chance that an initial investment of $10,000 in AAPL over the next 252 trading days will end within in the range of $5586.336518752442 and $17316.506780861942
